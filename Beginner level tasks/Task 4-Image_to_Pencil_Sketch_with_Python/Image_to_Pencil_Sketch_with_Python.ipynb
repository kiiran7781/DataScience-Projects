# %% [markdown]
# <a href="https://colab.research.google.com/github/kiiran7781/LGMVIP-DataScience-Kiran-K/blob/main/Beginner%20level%20tasks/Image_to_Pencil_Sketch_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Data Science Intern at Let's Grow More LGMVIP -Aug**
#
# ## **Beginner Level Task**
#
# ## **Image to Pencil Sketch with Python**
#
# ## **K Kiran**

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
def to_pencil_sketch(image):

    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    inverted_image = 255 - gray_image
    blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), sigmaX=0, sigmaY=0)
    inverted_blurred_image = 255 - blurred_image
    pencil_sketch = cv2.divide(gray_image, inverted_blurred_image, scale=256.0)
    desired_width = 800
    desired_height = 600
    resized_pencil_sketch = cv2.resize(pencil_sketch, (desired_width, desired_height))

    return resized_pencil_sketch

# %%
input_img = cv2.imread('/content/360_F_177476718_VWfYMWCzK32bfPI308wZljGHvAUYSJcn.jpg')

if input_img is None:
    print("Error: Image not loaded.")
else:
    pencil_sk = to_pencil_sketch(input_img)
    print
    cv2_imshow( input_img)
    cv2_imshow( pencil_sk)
# Out:
# <PIL.Image.Image image mode=RGB size=509x360>
# <PIL.Image.Image image mode=L size=800x600>
